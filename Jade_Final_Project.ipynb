# %% [markdown]
# # Final Project

# %% [markdown]
# ## Jade Benson

# %% [markdown]
# This notebook details my final project for the 2022 class "Cultural Patterns" where I use computational methods to identify cultural trends. I wanted to keep this notebook public for use in my portfolio - it can also be accessed on Github at: https://github.com/JadeBenson/Healthy_Food. I have split this notebook into two sections - the report and the analysis.

# %% [markdown]
# # Report

# %% [markdown]
# **Introduction**
#
#
# In this project, I am interested in exploring the discourse surrounding healthy food/eating and dieting on social media. ‘Diet culture’ has been used by feminist activists and researchers to critic the destructive norms surrounding dieting, food, and body policing for women (Jovanovski & Jaeger). These norms are based on moralistic hierarchies of what are considered good food and bodies. However, in recent years there has been pushback against these larger cultural norms surrounding food and dieting with subgroups like the “bodypositive,” “anti-diet,” and “intuitive eating” communities that are trying to define opposing conceptions of health, bodies, and eating to these larger cultural norms. However, these groups are just one small facet of the healthy food/eating online ecosystem. The fitness community is incredibly popular, with many influencers trying to market their diet plan or supporting diet trends that demonize particular food groups (i.e., keto or paleo). There may even be a third community of professionals (dietians, public health officials, doctors) who acknowledge the need for moderate diets to address the consequences of obesity (particularly in the US), while also recognizing how this problem is larger than just individual behaviors and includes food deserts, economic inequality, easy access to nutrient deficient foods, and corporate incentives. These different communities have competing definitions of what constitutes healthy food/eating and their perspectives on dieting.
#
#
# In order to explore these different communities and their discourses surrounding healthy food/eating and dieting, I will perform a cultural analysis using Twitter data. I scraped 34,331 tweets from March 1st, 2022 - March 8th, 2022 to explore discourse related to healthy food/eating or dieting. I have two primary research objectives. First, what are the topics discussed in healthy food/eating and dieting discourse on Twitter? Do these different topics help us identify the relevant subgroups with different conceptions of health, eating, and dieting within this discourse? Second, what is the proportion of moralistic language used in healthy food/eating and dieting Twitter discourse? One of the defining characteristics of “diet culture” is its use of hierarchies and moralistic language to influence eating and body practices. Do we see a high percentage of moralistic language overall in the discourse, what about in popular content, or different subgroups?

# %% [markdown]
# **Identification and Interpretation**
#
#
# In this analysis, I focus on representation from du Gay et al.’s Doing Cultural Studies (2013) cultural circuit theory. They define culture and its study through 5 interlocking processes: representation, identity, production, consumption, and regulation. Representation specifically focuses on how meaning is derived from representations in language. By examining the discourse and language surrounding healthy food/eating and dieting, I can better understand how meaning is created around body shaping practices. I primarily focus on representation in this analysis, but I am interested in expanding into identity as well since these different types of discourses can shape how various groups of people come to identify themselves. Given the different discourses, people may align themselves more with one type of ideal or another which shapes how they see themselves. For example, by discussing the best diet trends to lose fat and gain muscle and then practicing these techniques, I come to see myself as a fitness enthusiast. I am interested in understanding how people discuss healthy food/eating and dieting online and what this conveys about their underlying value system that shapes the meaning of that food and the bodies consuming it. Through understanding this representation, I can understand the culture surrounding healthy food/eating and dieting online.
#
# Stano (2016) argues that we can study words related to food descriptions as signs to understand culture:  the “need to lay the foundations of a proper semiotics of food arises: food is not only a substance for survival and nourishment, but also part of a sign system,” (20). He summarizes some fascinating work that explores how single terms have come to shape our understandings and valuations of food like Danesi’s study of “junk food” and Hernandez & Serra’s study of “nutrionalization.” I also examine how words (signs) are related to and convey meaning about peoples’ perspectives on eating and dieting. I examine tweets as objects and various words as sign-vehicles. For example, the sign-vehicle “healthy” is symbolically related to tweet (object) since it’s primarily through convention that words are linked to the object and meaning (it neither resembles, iconic, or is part of the object, indexical). The sign-vehicle then conveys an interpretant of health-promoting and good content. Most basically, this can be a rhematic symbolic legisign relationship where there is one word (healthy) that correlates conventionally (symbolic) with the object (tweet) to convey a general meaning or connotation (health/good). However, in our case, these relationships are often scaffolded to more complex layers where there could be argumentative symbolic legisigns where moralistic arguments are made about what constitutes healthy eating and dieting practices. I combine sign-vehicles together to roughly describe the interpretant of the moralistic language (junk, bad, immoral, clean, etc.) to identify the proportion of tweets that moralize healthy food/eating and dieting discourse. I additionally perform unsupervised topic modeling to try to extract these relationships between signs to identify similar sign-vehicles and hopefully, therefore, similar interpretants.

# %% [markdown]
# First, I wanted to identify if moralistic words were used in different subgroups in the discourse related to healthy eating/food and dieting on Twitter. In their literature review and qualitative survey of ‘diet culture,’ Jovanovski & Jaeger (2022) characterized it “as health myths about food and eating, and a moral hierarchy of bodies driven by systemic and structural factors.” Different restrictive diet communities particularly use moral vocabularies to enact collective self-discipline and, in doing so, define their identities and ideals as Atherton examines in her “Moralizing Hunger” (2021). Although not extensive, words related to moralistic language were selected and their occurrence was simply counted in tweets. As seen in Figure 1, out of all 34,331 tweets, only 8.2% included moralistic language. This was much less than I was expecting given the prior studies that found moralization as a defining aspect of this discourse. I think this discrepancy could be explained in a few ways: 1) I am examining all discourse related to healthy food/eating and dieting not particular subcommunities that may be more explicit in their use of language 2) this is a very coarse way of detecting moralistic language. There is no way to determine in this simple count whether “fat” is being used as an insult/fear word or as just a descriptor. This type of in-depth analysis would likely require a more qualitative approach that can discern these different contexts. We also see in figure 1 that the percentage of moralistic tweets drops even further for retweets. However, for the most popular content, indicated by likes, the moralistic percentage is much higher at 13.1%. This suggests that moralistic content may get more interaction online or may be more popular. This could be for a few reasons but perhaps it is because this content is purposefully controversial, boosting engagement or that more moralistic tweets are popular because they resonate with more people because of the predominant norms under diet culture.

# %% [markdown]
# ![alt text](moralistic_tweets.png "Proportion of Moralistic Tweets in Different Groups")

# %% [markdown]
# Next, I wanted to use more nuanced computational techniques to try to identify related sign-vehicles and if meaningful interpretants (topics) could be extracted from this discourse. Using Latent Dirichlet allocation (LDA) topic modeling, I identified 3 topics that were relatively distinct (given the PCA map and coherent values). I categorize these topics as follows (figure 2):

# %% [markdown]
# ![alt text](topic1.png "First Round of Topic Modeling: T1")

# %% [markdown]
# ![alt text](topic2.png "First Round of Topic Modeling: T2")

# %% [markdown]
# ![alt text](topic3.png "First Round of Topic Modeling: T3")

# %% [markdown]
# *Topic 1:* “Diet Culture”
# This is the largest (59% of tweets) and seemingly most negative topic. It’s represented by top words including fat, bad, sugar, junk food, weight, and expletives.
#
#
# *Topic 2:* “Wellness”
# This topic makes up 20% of the tweets and includes words like nutrition, recipe, organic, sustainable. It seems to be focused more on wellness and healthy eating as nutritious food.
#
#
# *Topic 3:* “Caring Tweets”
# This is the smallest topic (12%) and seems to be composed of people tweeting positive wishes at each other. The top tweets are all “good morning” where loved ones are wishing each other healthy, safe, and happy days ahead. The top words/phrases include: love, take_care, stay_safe, hydrate, good_morning, and well_soon.
#
# The first topic seems most in line with how feminist literature defines diet culture, including the moralistic language and perhaps fatphobia too. However, this second wellness topic may convey moral discourse too. The “wellness revolution” has led to new discourses surrounding health promotion and an expansion definition of wellness that is deeply moral (Conrad, 1994). This representation is deeply intertwined with identification (du Gay, 1997). As Tiusanen (2021) explores in their discourse analysis of wellness blogs, wellness language is very important to constructing subjectivity as it defines an individual’s aspirations (balance, healing, wholeness) and how they can achieve it through the right kind of consumption (organic, nutritious, sustainable). The last topic was surprising. After reading through the tweets, I had noticed there were many “happy birthday” wishes that were wishing friends healthy food and eating in their new year. I originally removed these since I thought they were irrelevant and not about healthy eating themselves. But there was an entire topic dedicated to this type of content! I have not been able to find much literature specifically discussing this type of online trend regarding healthy eating. I think this is better described by the social network maintaining functionality that social media allows its users. I didn’t think this was as popular on Twitter given my associations with the content being a little less personal/friend-based as other social medias.
#
# I then wanted to analyze if sentiment and moralistic language differed by these topics to further investigate whether this computation method was identifying relevant interpretants. The sentiment scores did vary greatly by topic. The Diet Culture topic was the most negative (0.26) as to be expected, where the Wellness topic was more mixed (0.53), and the Caring topic was unexpectedly quite positive (0.74). These sentiment scores are generally not able to pick up on sarcasm, which is often used in diet-related discourse. These negative scores may actually be misleading as they could include sarcasm, humor, and self-depreciation as a way to resist the moralizing and painful messaging of diet culture, as argued by Chaerani & Junaidi (2019).  The percentage of moralistic tweets was particularly different by topic (figure 3). The Diet Culture tweets had a much higher overall percentage than the other two (11.3% vs 3.1% vs. 3.3%) and a much higher proportion (some tweets were over a quarter moralistic words).

# %% [markdown]
# ![alt text](topics_morals_correct.png "Moralistic Percentage by Topic")

# %% [markdown]
# I was curious whether we could gain any further insight into this cultural pattern surrounding conceptions of healthy food/eating and dieting within the Diet Culture topic. After performing an additional topic analysis, 2 topics were identified. However, these did not add much insight except one looked like it was focused on veganism (top words: animal, plant_based, meat, suffer, veganism) and the other included a mix of words (top words: healthy, meal, weight, exercise). The high moral percentage in this topic could be coming particularly from the veganism subgroup as this diet practice often stems from an ideology based on the sanctity of life (Napoli & Ouschan, 2020).
#
# Lastly, this cultural analysis has primarily focused on representation, but I was interested in extending this to identification. However, it was more difficult to identify the relevant subgroups and how their discourse shapes them (and how they shift the discourse). Popular replies were overwhelmingly in the diet culture (90%). I think if I were to continue this project, I would query differently. I might pull specific Twitter users and their networks or more granular   healthy food/eating or diet topics like anti-fat/body positive to better access these subgroups.

# %% [markdown]
# **Conclusion**
#
#
# This research project attempted to identify and interpret patterns related to healthy food/eating and diet discourse on Twitter using natural language processing techniques. By analyzing words as sign-vehicles for interpretants related to moralization, I was able to identify representations of how people understand and conceptualize their eating practices. Although feminist literature has critiqued the wide-spread and destructive nature of “diet culture,” this relatively simple algorithms did not identify the same problem at scale. This is likely because the algorithm is not expansive enough to include all relevant moralization vocabulary and/or able to determine context-specific instances when words are being used to signal moral worth. However, moralistic content was particularly high among the most popular tweets which may suggest they either sparked controversy or approval. Topic modeling was able to distinguish three types of discourse related to diet culture, wellness, and caring. These discourses center around different conceptualizations of healthy food/eating and dieting: one focused on negative and moralizing language surrounding food and losing weight, another was composed of nutritious, organic, and sustainable food choices, and the last one was defined by loved ones wishing each other well. This suggests that the discourse is multifaceted and likely has different meanings depending on which cultural groups they are relevant to. Using computational methods, we are now able to study representations of digital culture at scale by mining vast amounts of peoples’ everyday thoughts and writing. I think future work should continue to prioritize a mixed methods approach where computational methods are informed by theory to better analyze cultural patterns. I look forward to continuing to practice these informed computational social science analyses.

# %% [markdown]
# **References**

# %% [markdown]
# Atherton, E. (2021). Moralizing Hunger: Cultural Fatphobia and the Moral Language of Contemporary Diet. *Feminist Philosophy Quarterly 7(3)*. https://ojs.lib.uwo.ca/index.php/fpq/article/view/10836/11373.
#
# Chaerani, A. R., & Junaidi, J. (2019). DOES DIET START TOMORROW? A DISCOURSE ANALYSIS OF SELF-DEPRECATING HUMOR AGAINST DIET CULTURE IN DIET STARTS TOMORROW. *Celtic : A Journal of Culture, English Language Teaching, Literature and Linguistics, 6(2)*, 51-62. https://doi.org/10.22219/celtic.v6i2.9940
#
# Conrad, P. (1994). Wellness as virtue: Morality and the pursuit of health. *Culture, Medicine and Psychiatry 18*, 385 – 401. https://link.springer.com/article/10.1007/BF01379232
#
# Du Gay, P. (1997). *Doing cultural studies : the story of the Sony Walkman*. Sage, in association with The Open University.
#
# Napoli, J. & Ouschan, R. (2020). Vegan stories: revealing archetypes and their moral foundations. *Qualitative Market Research, 23(1)*, 145 - 169. https://doi.org/10.1108/QMR-06-2018-0064.
#
# Jovanovski, N. & Jaeger, T. (2022) Demystifying ‘diet culture’: Exploring the meaning of diet culture in online ‘anti-diet’ feminist, fat activist, and health professional communities. *Women's Studies International Forum 90*. https://doi.org/10.1016/j.wsif.2021.102558
#
# Stano, S. (2016). Introduction: Semiotics of Food. *Semiotica* 211, 19 - 26. https:doi.org/10.1515/sem-2016-0095.
#
# Tiusanen, K. (2021) Fulfilling the self through food in wellness blogs: Governing the healthy subject. *European Journal of Cultural Studies* 24(6), 1382 - 1400.
# https://doi.org/10.1177/13675494211055734

# %% [markdown]
# # Analysis

# %% [markdown]
# I use the Twitter API to scrape all recent (3/1/22 - 3/8/22) tweets related to healthy food/eating and dieting. Ideally, this would be over a longer period of time or in a particularly relevant window like New Year's for resolutions, but this is what I can access with my free developer account and it gives us a sense of "normal" discourse surrounding these topics.  I think Twitter is perhaps the best social media site to use for this project because it includes so many diverse groups on the same platform. It also primarily centers around text conversations which allows us to better see how people are talking about these subjects. I think Tiktok may skew a little younger and more informal so would likely have fitness and body positive content, but perhaps not professionals. It also centers around videos more so than text and I'm interested in how people talk about these concepts - but it would be interesting to expand my skill set to try to get video transcriptions or how the images in videos relate to their short descriptions/tags. Reddit would be another option, but I am less familar with the pages that I would need to scrape to effectively cover these conversations.
#
#
# Deciding how to write a query that effectively picks up all these communities without grabbing too much irrelevant information is a big challenge. I'm trying to capture my idea of the three communities, but this might be baiting searches. If I am too granular with my searches, I might just be returning findings that I expect since I've filtered them to be that way, rather than capturing the potential complexities of larger cultural patterns. If I leave this query too broad, I may end up with irrelevant or disparate information which makes it challenging to find meaningful cohesive groups. I decided for a broad query "healthy and food" or "healthy and eat" or "diet and food" or "diet and eat" to try to pick up on multiple discourses to be further distinguished and analyzed.
#
# I perform a topic analysis where I try to assess how people are talking about healthy eating. I am curious about this "moralistic" dimension of discourse. However, I find this is a little more difficult to capture. Perhaps the phrase "clean eating" is easier to identify as moralistic since it's associating certain types of food and eating practices with being "clean" and others as "dirty." But how do we capture the moral dimension of "fat" since it's used in so many contexts? Fat could be mentioned as one of the macronutrients needed in a healthy diet, an insult or fear from so many online, or a reclaiming of the word to find neutraility in it as just a descriptive adjective as seen in the bodypositive community. This sort of different meanings of words for different groups is challenging to capture both without and certainly with computational methods.

# %%
import tweepy
from tweepy import OAuthHandler

import requests

import pandas as pd
import numpy as np
import csv
import re
import string
import time


import nltk
import gensim
from gensim import corpora, models
from gensim.utils import simple_preprocess 
from gensim.models import CoherenceModel

import pyLDAvis
from pyLDAvis import gensim_models 
import pickle 
import os
from pprint import pprint

import matplotlib.pyplot as plt

# %%
#Jade's Twitter API 2.0 info 
bearer_token = "AAAAAAAAAAAAAAAAAAAAAK%2FyZAEAAAAAknoZzdqGK6OIOejAHvMLFwAZ%2FaA%3DNm5WcRTGkrng2Jxg0ZQzuWfUGsqr1kJMtZKVuvSFMrjWsRiNPQ"

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FullArchiveSearchPython"
    return r

# %%
#params for recent search 
#https://developer.twitter.com/en/docs/twitter-api/tweets/search/api-reference/get-tweets-search-recent

def connect_to_endpoint(my_query, page_token):
    """
    Queries the API for 100 recent tweets using my_query for unique pages (token) 

    
    Input: 
        my_query: (str) consult the Twitter doc for formatting 
        page_token: (str) token returned by Twitter to track unique pages 
    
    Return: 
        dictionary of tweets, meta data, and token 
    """
     
    
    search_url = "https://api.twitter.com/2/tweets/search/recent"
    
    params = {'query': my_query,
            'expansions': "author_id,referenced_tweets.id,referenced_tweets.id.author_id,entities.mentions.username,in_reply_to_user_id,geo.place_id",
            'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings',
            'user.fields': 'description,id,location,name,url,username,verified',
            'max_results' : 100,
            'next_token': page_token}
    
    #defaults to scrape from start time of now to 7 days ago 
    
    response = requests.request("GET", search_url, auth=bearer_oauth, params=params)
    
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def process_batch_of_tweets(df_tweets, twitter_json): 
    """
    Processes scraped Twitter information and places it into a dataframe 
    Inputs: 
        df_tweets: (df) dataframe with columns for Twitter info 
        twitter_json: (json) returned information from Twitter query 
    
    Returns:
        dataframe with new info
    """
    
    for r in twitter_json['data']: 
        tweet_id = r['id']
        author_id = r['author_id']
        tweet_time = r['created_at']
        convo_id = r['conversation_id']

        tweet_text = r['text']

        num_retweets = r['public_metrics']['retweet_count']
        num_replies = r['public_metrics']['reply_count']
        num_likes = r['public_metrics']['like_count']
        num_quotes = r['public_metrics']['quote_count']

        if 'referenced_tweets' in r: 
            type_reference = r['referenced_tweets'][0]['type']
            referenced_tweet = r['referenced_tweets'][0]['id']

            if type_reference == 'replied_to':
                replied_to_user = r['in_reply_to_user_id']
            else: 
                replied_to_user = None
        else:
            type_reference = None
            referenced_tweet = None
            replied_to_user = None

        #just add the dictionaries to df for now 
        #can figure out if/how to keep these later
        if 'entities' in r: 
            mentions_dict = r['entities']
        else: 
            mentions_dict = None 

        if 'includes' in r: 
            includes_dict = r['includes']
        else: 
            includes_dict = None


         # Add the 11 variables to the empty list - ith_tweet:
        ith_tweet = [tweet_id,
                     author_id,
                     tweet_time,
                     convo_id, 
                     tweet_text,
                     num_retweets, 
                     num_replies, 
                     num_likes, 
                     num_quotes, 
                     type_reference, 
                     referenced_tweet, 
                     replied_to_user, 
                     mentions_dict, 
                     includes_dict
                     ]
        # Append to dataframe - db_tweets
        df_tweets.loc[len(df_tweets)] = ith_tweet

# %%
def scrape_Twitter(my_query, num_batches):
    """
    Scrapes recent Twitter data using query for number of batches with 100 Tweets 
    
    Inputs: 
        my_query: (str) formatted query for Twitter API 
        num_batches: (int) number of batches of 100 to run 
    
    Returns: 
        df with Twitter information 
        csv with Twitter information
    """
    
    program_start = time.time()
    
    page_token = {}
    
    newest_id = {}
    
    df_tweets = pd.DataFrame(columns = ['tweet_id',
                                        'author_id',
                                        'tweet_created_at',
                                        'conversation_id',
                                        'text',
                                        'retweets', 
                                         'replies', 
                                         'likes', 
                                         'quotes', 
                                         'type_reference',
                                         'referenced_tweet',
                                         'replied_to_user', 
                                         'mentions_dict',
                                         'thread_dict'                                     
                                       ])

    
    for b in range(num_batches): 
        
        batch_start = time.time()
        
        twitter_json = connect_to_endpoint(my_query, page_token)
        
       
        process_batch_of_tweets(df_tweets, twitter_json) 
        
        
        try: 
            page_token = twitter_json["meta"]['next_token']
        
        except: 
            print("No more new responses")
            break
            
        batch_end = time.time()
        
        batch_run = round((batch_end-batch_start)/60, 2)
        
        print('Batch {} completed in {} mins'.format(b, batch_run))
        
        
        #might need to sleep here to avoid timing out API 
        #time.sleep(920) #15 minute sleep time

    
    #will update this with time of scraping when scaled up
    filename = "Twitter_final_38.csv"
    
    df_tweets.to_csv(filename, index = False)
    
    program_end = time.time()
    
    scrape_end = round((program_end-program_start)/60, 2)

    print("Scraping done! Time elapsed is {} mins".format(scrape_end))
    
    return df_tweets

# %%
#build a query guide 
#https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/build-a-query 
#words in parathenses is an AND 

#I decided to keep this simpler to capture all discussions about healthy eating/food and dieting 
my_query = "((healthy food) OR (healthy eat) OR (diet eat) OR (diet food)) lang:en"

# %%
#scrape a maximum of 100,000 tweets 
#this will allow for effective topic modeling 
#but also hopefully be manageable for network analysis 

tweets_df = scrape_Twitter(my_query, 1000)
# Out:
# Batch 0 completed in 0.02 mins
# Batch 1 completed in 0.02 mins
# Batch 2 completed in 0.02 mins
# Batch 3 completed in 0.02 mins
# Batch 4 completed in 0.02 mins
# Batch 5 completed in 0.03 mins
# Batch 6 completed in 0.02 mins
# Batch 7 completed in 0.03 mins
# Batch 8 completed in 0.02 mins
# Batch 9 completed in 0.02 mins
# Batch 10 completed in 0.02 mins
# Batch 11 completed in 0.02 mins
# Batch 12 completed in 0.03 mins
# Batch 13 completed in 0.02 mins
# Batch 14 completed in 0.02 mins
# Batch 15 completed in 0.02 mins
# Batch 16 completed in 0.02 mins
# Batch 17 completed in 0.02 mins
# Batch 18 completed in 0.02 mins
# Batch 19 completed in 0.02 mins
# Batch 20 completed in 0.02 mins
# Batch 21 completed in 0.02 mins
# Batch 22 completed in 0.02 mins
# Batch 23 completed in 0.02 mins
# Batch 24 completed in 0.02 mins
# Batch 25 completed in 0.02 mins
# Batch 26 completed in 0.02 mins
# Batch 27 completed in 0.02 mins
# Batch 28 completed in 0.02 mins
# ...

# %%
len(tweets_df)
# Out:
# 70566

# %%
#make sure unique tweets!
len(tweets_df['tweet_id'].unique())
# Out:
# 70566

# %%
#had some difficulty with people repeatedly tweeting the same thing
#often at celebrities about recent news about their eating/diets 
#remove these so it doesn't skew results 
#38,590 unique text responses 
print(len(tweets_df['text'].unique()) )
# Out:
# 34331

# %%
tweets_df = tweets_df.drop_duplicates(subset=['text'])

# %%
tweets_df = tweets_df.reset_index(drop=True)

# %%
tweets_df.tail()
# Out:
#        level_0  index             tweet_id            author_id  \
# 34326    38585  70557  1498735815945748480  1442914948208754688
# 34327    38586  70558  1498735761255911426             33781112
# 34328    38587  70559  1498735728263680010           3673723843
# 34329    38588  70561  1498735679198609418           1729944090
# 34330    38589  70563  1498735570838712324           4562447776
#
#                tweet_created_at      conversation_id  \
# 34326  2022-03-01T19:03:58.000Z  1498735815945748480
# 34327  2022-03-01T19:03:45.000Z  1498735761255911426
# 34328  2022-03-01T19:03:37.000Z  1498735728263680010
# 34329  2022-03-01T19:03:25.000Z  1498671811785019403
# 34330  2022-03-01T19:02:59.000Z  1498735570838712324
#
#                                                     text retweets replies  \
# 34326  The GODLIKE https://t.co/QzvJrSKglm #dinnerrec...        0       0
# 34327  Wonderful Wednesday! #6amClub #wellness sessio...        0       3
# ...

# %%
len(tweets_df)
# Out:
# 34331

# %%
#initial text cleaning 
#remove links, mentions with usernames, and non-letters 
clean_f = lambda x: ' '.join(re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x).split())
tweets_df["clean_text"] = tweets_df["text"].apply(clean_f)

#remove "RT" in these too 
remove_RT = lambda x: x.replace('RT ', '')
tweets_df["clean_text"] = tweets_df["clean_text"].apply(remove_RT)

# %%
#this looks a little better
tweets_df.head()
# Out:
#    level_0  index             tweet_id            author_id  \
# 0        0      0  1501259958511443969           4909860786
# 1        1      1  1501259930141036545   968843336961290241
# 2        2      2  1501259905298165760              7610242
# 3        3      3  1501259892283240453  1296735798239178752
# 4        4      4  1501259812394446860           1863340376
#
#            tweet_created_at      conversation_id  \
# 0  2022-03-08T18:14:00.000Z  1501259958511443969
# 1  2022-03-08T18:13:54.000Z  1501255817051394055
# 2  2022-03-08T18:13:48.000Z  1501259905298165760
# 3  2022-03-08T18:13:45.000Z  1501259892283240453
# 4  2022-03-08T18:13:25.000Z  1501259812394446860
#
#                                                 text retweets replies likes  \
# 0  I’ll eat salad and green juice and coffeee my ...        0       0     0
# 1  @KevinRothrock It is good for Russian's health...        0       0     0
# ...

# %%
#there was also a lot of advertising spamming where it was mentioning different people but the same text 
#the content analysis picked this up 
#but it doesn't tell us much about cultural patterns 
#except perhaps Twitter scams and multilevel marketing for diets (which is a BIG thing)
len(tweets_df['clean_text'].unique())
# Out:
# 34331

# %%
tweets_df = tweets_df.drop_duplicates(subset=['clean_text'])
tweets_df = tweets_df.reset_index(drop=True)

# %%
#save this cleaned dataframe 
tweets_df.to_csv("cleaned_full_tweets.csv",  index = False)

# %%
#start here when re-loading

# %%
tweets_df = pd.read_csv("cleaned_full_tweets.csv")

# %%
tweets_df.head()
# Out:
#    level_0  index             tweet_id            author_id  \
# 0        0      0  1501259958511443969           4909860786
# 1        1      1  1501259930141036545   968843336961290241
# 2        2      2  1501259905298165760              7610242
# 3        3      3  1501259892283240453  1296735798239178752
# 4        4      4  1501259812394446860           1863340376
#
#            tweet_created_at      conversation_id  \
# 0  2022-03-08T18:14:00.000Z  1501259958511443969
# 1  2022-03-08T18:13:54.000Z  1501255817051394055
# 2  2022-03-08T18:13:48.000Z  1501259905298165760
# 3  2022-03-08T18:13:45.000Z  1501259892283240453
# 4  2022-03-08T18:13:25.000Z  1501259812394446860
#
#                                                 text  retweets  replies  \
# 0  I’ll eat salad and green juice and coffeee my ...         0        0
# 1  @KevinRothrock It is good for Russian's health...         0        0
# 2  RT @Pinealpodcast: Why do you know the names o...         3        0
# ...

# %%
clean_tweets = tweets_df['clean_text']

# %%
clean_tweets.head(20)
# Out:
# 0     I ll eat salad and green juice and coffeee my ...
# 1     It is good for Russian s health Fast junk food...
# 2     Why do you know the names of towns in Ukraine ...
# 3     Happy birthday yoongi oppa always stay healthy...
# 4     God Help me to love my future self enough to b...
# 5     just youngjae reminding ahgases to make sure t...
# 6     Amie A look at higher meat prices Read more an...
# 7     happy birthday our precious lovely girl seo so...
# 8     Woo hoo If McRib comes back I can have one I a...
# 9     Russians will now eat only healthy food Win Wi...
# 10    Me at night before bed Tomorrow I m going to e...
# 11    So after a big tech fake news wokeism cleanse ...
# 12    i didnt want to publicly say this but it felt ...
# 13    Good morning to our angel baby our sunshine ke...
# 14    Why eat more cucumbers 95 water rich in fibre ...
# 15    Take the train of thought out of your mind tha...
# 16    Reducing food waste is an important way we can...
# ...

# %% [markdown]
# First, let's perform a simplistic analysis to see if "moralistic" language is being used. Again, I think that this is difficult to properly capture. I'm going to go with something very basic for this initial test for a proof of concept, but hopefully the topics will pick up on more nuance.

# %%
# Thank you Jon! I've written attempts at these that are much messier - this makes everything easier :)  

def get_wordnet_pos(word):
    '''
    Tags each word with its Part-of-speech indicator -- specifically used for lemmatization in the get_lemmas function
    '''
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {'J': nltk.corpus.wordnet.ADJ,
                'N': nltk.corpus.wordnet.NOUN,
                'V': nltk.corpus.wordnet.VERB,
                'R': nltk.corpus.wordnet.ADV}

    return tag_dict.get(tag, nltk.corpus.wordnet.NOUN)

def get_lemmas(text):
    '''
    Gets lemmas for a string input, excluding stop words, punctuation
    '''
    # Define stop words
    my_stops = ['re', 'also', 'lot', 'around', 'as']
    stop = nltk.corpus.stopwords.words('english') + list(string.punctuation) + my_stops
    
    # Combine list elements together into a single string to use NLTK's tokenizer
    #our text is already a single string - don't need this
    #text = ' '.join(text)
    #print("text: " , text)
    
    # tokenize + lemmatize words in text 
    #only include if longer than 1 character (weird single letters/numbers)
    tokens = [i for i in nltk.word_tokenize(text.lower()) if i not in stop and len(i) > 2]
    #print("tokens: " , tokens)

    lemmas = [nltk.stem.WordNetLemmatizer().lemmatize(t, get_wordnet_pos(t)) for t in tokens]
    #print("lemmas: " , lemmas)

    return lemmas

def get_tokens(text):
    '''
    Gets all tokens (including stop words), excluding punctuation
    '''
    # drop punctuation, but keep stopwords for initial word counting
    text = text.translate(str.maketrans('', '', string.punctuation))

    # tokenize remaining words and make a list of them for input `text`
    tokens = [i for i in nltk.word_tokenize(text.lower())]
    return tokens

# %% [markdown]
# ### Moralistic Tweets

# %%
def simple_moralistic_perc(text): 
    #Jon also wrote this function - just tweaking for my use
    
    #get text with stopwords still included
    text = get_tokens(text)
    
    #is this moral or disgust? 
    #I definitely think these are related but the same? 
    moral_count = (text.count("moral")
                        + text.count("immoral")
                        + text.count("should")
                       + text.count("clean")
                       + text.count("bad")
                       + text.count("junk")
                        + text.count("gross")
                          + text.count('naughty')
                          +text.count("wrong"))
    return moral_count /len(text)

# %%
total_moral_per = clean_tweets.apply(simple_moralistic_perc)

# %%
plt.hist(total_moral_per)
plt.ylabel("Number of Tweets")
plt.xlabel("Proportion Moralistic Language");

# %%
def moral_percentage(moral_per):
    count = 0
    for m in moral_per: 
        if m > 0: 
            count+=1
    print("Number of moralistic tweets: ", count)
    print("Percentage of moralistic in full sample: ", (count / len(moral_per))*100)

# %%
moral_percentage(total_moral_per)
# Out:
# Number of moralistic tweets:  2814
# Percentage of moralistic in full sample:  8.196673560339052

# %% [markdown]
# Seems like overall, very few tweets use this type of language. This may be a good thing that I'm only picking up a little bit of the fatphobia and harassment which persists online. However, there is a small group that is using moralistic language quite frequently. It may be worth looking at those tweets with very high moralistic percentages to see what type of subjects they're talking about and better understand how and why this language is being used.

# %%
#what does the moralistic tweet percentage look like among retweets? 
retweets_df = tweets_df[tweets_df['type_reference'] == 'retweeted']

# %%
retweets = retweets_df['clean_text']

# %%
retweets_moral_per = retweets.apply(simple_moralistic_perc)

# %%
plt.hist(retweets_moral_per)
plt.ylabel("Number of Tweets")
plt.xlabel("Proportion Moralistic Language");

# %%
moral_percentage(retweets_moral_per)
#lower among the retweets than the overall content, that's interesting
# Out:
# Number of moralistic tweets:  295
# Percentage of moralistic in full sample:  4.996612466124661

# %%
#what's the moralistic count among the top 1,000 most liked tweets? 
most_liked_tweets = tweets_df.sort_values(['likes'], ascending=False)

# %%
most_liked_tweets.head()
# Out:
#        level_0  index             tweet_id            author_id  \
# 32684    36663  66964  1498851287365992453   775094419175374850
# 16608    18497  30669  1500033898411028481  1279907313218752512
# 12281    13500  21711  1500443619404435461  1024168073635422208
# 7677      8163  12738  1500803446131150852  1343737712570863616
# 3667      3853   5976  1501042612974718980  1081672489690951680
#
#                tweet_created_at      conversation_id  \
# 32684  2022-03-02T02:42:48.000Z  1498690412999020545
# 16608  2022-03-05T09:02:05.000Z  1500033898411028481
# 12281  2022-03-06T12:10:10.000Z  1500443619404435461
# 7677   2022-03-07T11:59:59.000Z  1500803446131150852
# 3667   2022-03-08T03:50:21.000Z  1501038758203772928
#
#                                                     text  retweets  replies  \
# 32684  @ambernoelle my mom would get so mad when i wo...        67        8
# 16608  no linoribang car vlive and leeknow has been l...       545        3
# ...

# %%
most_liked_tweets = most_liked_tweets.iloc[0:1000, :]

# %%
liked_tweets = most_liked_tweets['clean_text']

# %%
liked_moral_per = liked_tweets.apply(simple_moralistic_perc)

# %%
plt.hist(liked_moral_per)
plt.ylabel("Number of Tweets")
plt.xlabel("Proportion Moralistic Language");

# %%
moral_percentage(liked_moral_per)
#much higher percentage here - that's interesting
# Out:
# Number of moralistic tweets:  131
# Percentage of moralistic in full sample:  13.100000000000001

# %%
#what do the most moralistic tweets look like?
index_counter = 0 
i_m_list = []
for m in total_moral_per: 
    if m > 0.20: 
        i_m_list.append([index_counter, m])
    index_counter +=1

# %%
i_m_list
# Out:
# [[17200, 0.25], [25492, 0.3333333333333333]]

# %%
tweets_df.iloc[i_m_list[0][0], :]
# Out:
# level_0                                                         19124
# index                                                           31570
# tweet_id                                          1499996197641404418
# author_id                                         1379985064142901254
# tweet_created_at                             2022-03-05T06:32:16.000Z
# conversation_id                                   1499995625085370373
# text                            @GAHunterFess Healthy food/junk food?
# retweets                                                            0
# replies                                                             0
# likes                                                               0
# quotes                                                              4
# type_reference                                             replied_to
# referenced_tweet                                1499995625085370368.0
# ...

# %%
tweets_df.iloc[i_m_list[1][0], :]
# Out:
# level_0                                                   28646
# index                                                     50936
# tweet_id                                    1499384028952023040
# author_id                                   1271383802326077441
# tweet_created_at                       2022-03-03T13:59:44.000Z
# conversation_id                             1499384028952023040
# text                Healthy junk food 😋 https://t.co/edpnaoJEx8
# retweets                                                      0
# replies                                                       0
# likes                                                         0
# quotes                                                        0
# type_reference                                              NaN
# referenced_tweet                                            NaN
# replied_to_user                                             NaN
# mentions_dict                                               NaN
# ...

# %% [markdown]
# Looks like these moralistic tweets are trying to decide whether food is "healthy" or "junk" and whether "junk" food can be made healthy.

# %%
#plot all moralistic graphs together

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (10,5))
fig.suptitle('Proportion of Moralistic Tweets')

ax1.hist(total_moral_per)
ax1.set_title("All Tweets: 8.2%")

ax2.hist(retweets_moral_per)
ax2.set_title("Retweets: 5.0%")

ax3.hist(liked_moral_per)
ax3.set_title("Most Liked Tweets: 13.1%");

# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# Let's move on to topic modeling and hope that this gives us more useful information about the type of language used to discuss healthy eating.

# %% [markdown]
# After reading though these tweets to get a sense of what's included, there are a lot of tweets wishing friends or celebrities happy birthday and that they hope they are eating healthy. This will be one of the topics I discuss in my report since I was surprised. I'm going to remove these from the overall data set though to try to understand other topics within the discourse.

# %%
tweets_df.head()
# Out:
#    level_0  index             tweet_id            author_id  \
# 0        0      0  1501259958511443969           4909860786
# 1        1      1  1501259930141036545   968843336961290241
# 2        2      2  1501259905298165760              7610242
# 3        3      3  1501259892283240453  1296735798239178752
# 4        4      4  1501259812394446860           1863340376
#
#            tweet_created_at      conversation_id  \
# 0  2022-03-08T18:14:00.000Z  1501259958511443969
# 1  2022-03-08T18:13:54.000Z  1501255817051394055
# 2  2022-03-08T18:13:48.000Z  1501259905298165760
# 3  2022-03-08T18:13:45.000Z  1501259892283240453
# 4  2022-03-08T18:13:25.000Z  1501259812394446860
#
#                                                 text  retweets  replies  \
# 0  I’ll eat salad and green juice and coffeee my ...         0        0
# 1  @KevinRothrock It is good for Russian's health...         0        0
# 2  RT @Pinealpodcast: Why do you know the names o...         3        0
# ...

# %%
remove_birthday_tweets = lambda x: x.find('birthday')
tweets_df["birthday"] = tweets_df["clean_text"].apply(remove_birthday_tweets)

# %%
tweets_df.head()
# Out:
#    level_0  index             tweet_id            author_id  \
# 0        0      0  1501259958511443969           4909860786
# 1        1      1  1501259930141036545   968843336961290241
# 2        2      2  1501259905298165760              7610242
# 3        3      3  1501259892283240453  1296735798239178752
# 4        4      4  1501259812394446860           1863340376
#
#            tweet_created_at      conversation_id  \
# 0  2022-03-08T18:14:00.000Z  1501259958511443969
# 1  2022-03-08T18:13:54.000Z  1501255817051394055
# 2  2022-03-08T18:13:48.000Z  1501259905298165760
# 3  2022-03-08T18:13:45.000Z  1501259892283240453
# 4  2022-03-08T18:13:25.000Z  1501259812394446860
#
#                                                 text  retweets  replies  \
# 0  I’ll eat salad and green juice and coffeee my ...         0        0
# 1  @KevinRothrock It is good for Russian's health...         0        0
# 2  RT @Pinealpodcast: Why do you know the names o...         3        0
# ...

# %%
no_birthday_tweets = tweets_df[tweets_df['birthday']==-1]

# %%
len(tweets_df) - len(no_birthday_tweets)
#removed a few tweets, hopefully this will help since so many names were throwing off the modeling earlier 
#should have removed mentions in a different way
# Out:
# 346

# %%
clean_tweets = no_birthday_tweets['clean_text']

# %%
#lemmatize our text 
lemmas = [get_lemmas(tweet) for tweet in clean_tweets]

# %%
lemmas[0:5]
# Out:
# [['eat', 'salad', 'green', 'juice', 'coffeee', 'new', 'diet'],
#  ['good',
#   'russian',
#   'health',
#   'fast',
#   'junk',
#   'food',
#   'ban',
#   'russia',
#   'opportunity',
#   'local',
#   'healthy',
#   'food',
#   'restaurant'],
#  ['know',
#   'name',
#   'town',
#   'ukraine',
#   'whole',
#   'food',
#   'plant',
#   'base',
#   'diet',
#   'prevent',
#   'reverse',
#   'heart'],
#  ['god',
#   'help',
#   'love',
#   'future',
#   'self',
#   'enough',
#   'healthy',
#   'today',
#   'even',
#   'though',
#   'really',
#   'want',
#   'eat'],
#  ['youngjae',
#   'remind',
#   'ahgases',
#   'make',
#   'sure',
#   'eat',
#   'end',
#   'stay',
#   'healthy',
#   'love',
#   'see']]

# %% [markdown]
# Ukraine and Russia content which makes sense given the recent world events.

# %%
#create bigrams if they appear > 5 times
bigram = models.Phrases(lemmas, min_count = 5)
bigram_mod = models.phrases.Phraser(bigram)
bigram_lemmas = [bigram_mod[word] for word in lemmas]

# %%
bigram_lemmas[0:5]
#some interesting ones 
#obviously a lot of advertising here with "next_app" and "ad" appearing so often 
#"lifestyle_fitness" "anxiety_pain" "body_type" "climate_change" "lose_weight" politician names "balance diet"
# Out:
# [['eat', 'salad', 'green', 'juice', 'coffeee', 'new', 'diet'],
#  ['good',
#   'russian',
#   'health',
#   'fast',
#   'junk_food',
#   'ban',
#   'russia',
#   'opportunity',
#   'local',
#   'healthy',
#   'food',
#   'restaurant'],
#  ['know',
#   'name',
#   'town',
#   'ukraine',
#   'whole',
#   'food',
#   'plant_base',
#   'diet',
#   'prevent',
#   'reverse',
#   'heart'],
#  ['god',
#   'help',
#   'love',
#   'future',
#   'self',
#   'enough',
#   'healthy',
#   'today',
#   'even_though',
#   'really',
#   'want',
#   'eat'],
#  ['youngjae',
#   'remind',
#   'ahgases',
#   'make_sure',
#   'eat',
#   'end',
#   'stay',
#   'healthy',
#   'love',
#   'see']]

# %%
dictionary = corpora.Dictionary(bigram_lemmas)
bow_corpus = [dictionary.doc2bow(text) for text in bigram_lemmas]

# %%
Lda = gensim.models.ldamodel.LdaModel

# %%
def calc_plot_coherence(smallest_n, largest_n, bow_corpus, dictionary, bigram_lemmas): 
    """
    Calculates the coherence for varing topic numbers 
    """
    coherence = []

    for k in range(smallest_n,largest_n):

        print('Topics: '+str(k))

        #these are parameters that I think will work based on gensim's documentation and some other googling
        #it takes a long time for this to run but ideally would want to do a grid search with all hyperparameters
        #could work on parallelizing this for the future

        ldamodel = Lda(corpus = bow_corpus, num_topics=k, id2word = dictionary, random_state = 42,\
            passes=5, chunksize = 1000, iterations = 10, alpha = 'auto', eta = 'auto', eval_every = None)

        cm = CoherenceModel(model=ldamodel, corpus=bow_corpus, coherence='u_mass')

        print("number of topics: ", k, "u mass coherence: ", cm.get_coherence())
        
        coherence.append((k, cm.get_coherence()))
    
    #plot this
    x_val = [x[0] for x in coherence]
    y_val = [x[1] for x in coherence]


    plt.plot(x_val,y_val)
    plt.scatter(x_val,y_val)
    plt.title('Number of Topics vs. UMass Coherence')
    plt.xlabel('Number of Topics')
    plt.ylabel('Coherence')
    plt.xticks(x_val)
    plt.show()

# %%
calc_plot_coherence(2, 10, bow_corpus, dictionary, bigram_lemmas)
# Out:
# Topics: 2
# number of topics:  2 u mass coherence:  -3.087745646342422
# Topics: 3
# number of topics:  3 u mass coherence:  -3.1467177551257532
# Topics: 4
# number of topics:  4 u mass coherence:  -4.244201785455879
# Topics: 5
# number of topics:  5 u mass coherence:  -4.1897821189745885
# Topics: 6
# number of topics:  6 u mass coherence:  -5.525188422187335
# Topics: 7
# number of topics:  7 u mass coherence:  -6.338937788025598
# Topics: 8
# number of topics:  8 u mass coherence:  -7.589590217575888
# Topics: 9
# number of topics:  9 u mass coherence:  -6.371284337796508

# %% [markdown]
# It looks like 2 or 3 topics fits the best! For now, no hyperparameter tuning, let's just look at these topics first

# %% [markdown]
# ## Topic Visualization

# %%
def LDA_visualize(my_corpus, my_num_topics, my_id2word, my_passes, my_chunksize, my_iter, my_alpha, my_beta, name): 
    """
    Runs an LDA model with the above specifications 
    Saves model in a pickle 
    Prints the model to an HTML to visualize 
    """
    #build LDA model 
    Lda = gensim.models.ldamodel.LdaModel


    lda_model = Lda(corpus=my_corpus, num_topics=my_num_topics, id2word = my_id2word, random_state = 42,\
                    passes=my_passes, chunksize = my_chunksize, iterations = my_iter, eval_every = None,\
                    alpha = my_alpha, eta = my_beta)
    
    cm = CoherenceModel(model=lda_model, corpus=my_corpus, coherence='u_mass')
    
    print("coherence is: ", cm.get_coherence())

    #print keyword in the topics - see if this is a good split? 
    pprint(lda_model.print_topics())

    # Visualize the topics
    pyLDAvis.enable_notebook()

    LDAvis_data_filepath = "ldavis"+ name


    if 1 == 1:
        LDAvis_prepared = pyLDAvis.gensim_models.prepare(lda_model, my_corpus, my_id2word)
        with open(LDAvis_data_filepath, 'wb') as f:
            pickle.dump(LDAvis_prepared, f)

    # load the pre-prepared pyLDAvis data from disk
    with open(LDAvis_data_filepath, 'rb') as f:
        LDAvis_prepared = pickle.load(f)

    pyLDAvis.save_html(LDAvis_prepared, LDAvis_data_filepath +'.html')

# %%
#visualize the most coherent topic model 
LDA_visualize(bow_corpus, 3, dictionary, 5, 1000, 10, "auto", "auto", "max_coherence_3_18") 
#this doesn't mean much/anything to me 
#they all look pretty similar... 
#actually when the relevance metric is turned to 0.0 these do look different and interesting/important
# Out:
# coherence is:  -3.1467177551257532
# [(0,
#   '0.053*"eat" + 0.036*"food" + 0.035*"healthy" + 0.032*"diet" + 0.011*"get" + '
#   '0.010*"like" + 0.008*"make" + 0.007*"people" + 0.007*"want" + 0.007*"need"'),
#  (1,
#   '0.072*"healthy" + 0.061*"eat" + 0.019*"stay" + 0.019*"love" + 0.017*"day" + '
#   '0.016*"always" + 0.016*"today" + 0.015*"good" + 0.011*"well" + '
#   '0.009*"breakfast"'),
#  (2,
#   '0.068*"food" + 0.037*"healthy" + 0.013*"health" + 0.012*"amp" + '
#   '0.011*"diet" + 0.007*"make" + 0.007*"nutrition" + 0.007*"recipe" + '
#   '0.006*"help" + 0.006*"learn"')]

# %% [markdown]
# Although these topics look the same from their print-out, when the relevance is adjusted to 0 - three very different topics do emerge.
#
# *Topic 1:*  Is the largest and most negative topic. I would consider this the "diet culture" topic group. Some of the top words include fat, bad, sugar, junk food, weight, and expletives.
#
#
# *Topic 2:* This seems to be the recipe / fitness content. It's top words include nutrition, recipe, organic, sustainable. It seems to be focused more on wellness and healthy eating as nutritious food.
#
#
# *Topic 3:* Is the smallest topic and seems to be one about caring for other people. As seen with the happy birthday tweets, there is a lot of twitter content between users wishing the best for each other. This seems to be that topic with the top words/phrases including: love, take_care, stay_safe, hydrate, good_morning, and well_soon.

# %%
no_birthday_tweets.reset_index(inplace=True, drop =True)

# %%
#Thank you again for these Jon! Much cleaner than what I've tried before 

def fill_topic_weights(df_row, bow_corpus, ldamodel):
    '''
    Fill DataFrame rows with topic weights for topics in songs.
    
    Modifies DataFrame rows *in place*.
    '''
    try:
        for i in ldamodel[bow_corpus[df_row.name]]:
            df_row["Topic_" + str(i[0])] = i[1]
    except:
        return df_row
    return df_row

def top_tweets_by_topic(tweet_df, ldamodel, corpus, ntop=1):
    '''
    Finds the top "n" tweets by topic, which we can use for
    understanding the types of tweets included in a topic.
    '''
    topn_tweets_by_topic = {}
    for i in range(len(ldamodel.print_topics())):
        # For each topic, collect the most representative tweets(s)
        # (i.e. highest probability containing words belonging to topic):
        top = sorted(zip(range(len(corpus)), ldamodel[corpus]), 
                     reverse=True, 
                     key=lambda x: abs(dict(x[1]).get(i, 0.0)))
        topn_tweets_by_topic[i] = [j[0] for j in top[:ntop]]
        
        # Print out the topn tweets for each topic and return their indices as a dictionary for further analysis:
        print("Topic " + str(i))
        print(no_birthday_tweets[['tweet_id','text']].loc[topn_tweets_by_topic[i]])
        print("*******************************")
    
    return topn_tweets_by_topic

# %%
#just to make sure right ldamodel 
lmax_coherence_lda_model = Lda(corpus=bow_corpus, num_topics=3, id2word = dictionary, random_state = 42,\
                    passes=5, chunksize = 1000, iterations = 10, eval_every = None,\
                    alpha = 'auto', eta = 'auto')

# %%
top_tweets_by_topic = top_tweets_by_topic(no_birthday_tweets, lmax_coherence_lda_model, bow_corpus, ntop=10)
# Out:
# Topic 0
#                   tweet_id                                               text
# 26994  1499221665531654146  @vegan_front @MrJosh0634 Veganism is a diet. a...
# 2667   1501112676210311168  @milkuettes I simply followed omad diet and on...
# 27518  1499181931363196928  @Dragon_Age_Fans @AITA_online My mum didn't le...
# 17243  1499958320337240064  @september_audio It was so good! I could eat i...
# 32690  1498827862606032900  @ThatKevinSmith I gotta be honest, I never see...
# 3911   1501009703710740481  The ruling class:\n\nYou don't like gas prices...
# 12521  1500389015421337601  @emmyboro @Bosonn_ @sportbible I beg to differ...
# 27155  1499209626532954113  mine is definitely mainly fatigue like i feel ...
# 27925  1499152194519584779  @InsiderLife @girlscouts It's COOKIES for God'...
# 4186   1500989476901896195  @stone_relief Varies from year to year as to h...
# *******************************
# Topic 1
# ...

# %%
#these can be a little difficult to fully read 
#this looks like the negative topic (1)
no_birthday_tweets.iloc[26994, -2]
# Out:
# 'front Veganism is a diet a Karen is a person that thinks they can ruffle someone s feathers to make them act or in this case eat another way Don t wanna wear a mask act like a Karen don t want a Vax act like a Karen mad that your diet resembles a cult act like a Karen Weird'

# %%
#this looks like the caring for other people topic (3)
no_birthday_tweets.iloc[4102, -2]
# Out:
# 'GOOD MORNING TO MY BFF HI thank u sm i ll eat maya maya ikaw din ha wag skip ng meals para healthy tsaka water drink ikaw dami gluck if may tasks ka today dont forget to take breaks in between love u more chismisan today sana HAHAHSD take care babe have a lovely day'

# %%
#this looks like the nutrition topic (2)
no_birthday_tweets.iloc[22113, -2]
# Out:
# 'Recommendation 3 Reorient food environments to prioritise healthy and sustainable foods i food labelling scheme integrating health amp ecological outcomes ii settings based approaches and iii supportive federal amp state policy to facilitate local government action'

# %%
#It looks like this text could use more cleaning still 
#a lot of non English words in it and words that don't make a lot of sense (amp?)

# %% [markdown]
# This topic modeling has pulled out three very interesting topics that I didn't expect to find. It looks like one is more overtly negative, another is focused on nutrition, and a third is about people sending good wishes to each other. I think there is still a lot of data cleaning to be done to better filter out non-English words, extra stop words that don't make sense and usernames. However, this is much better than my preliminary round in assignment 2 which was picking up pornographic content because I had "bodypositive" in the query and a lot of spam messages (which I filtered out by getting rid of identical text).

# %%
topics_tweets = no_birthday_tweets.apply(fill_topic_weights,
                          axis=1, args=[bow_corpus, lmax_coherence_lda_model]).fillna(0)

# %%
topics_tweets.head()
# Out:
#    level_0  index             tweet_id            author_id  \
# 0        0      0  1501259958511443969           4909860786
# 1        1      1  1501259930141036545   968843336961290241
# 2        2      2  1501259905298165760              7610242
# 3        4      4  1501259812394446860           1863340376
# 4        5      5  1501259781876568071  1000009052615659520
#
#            tweet_created_at      conversation_id  \
# 0  2022-03-08T18:14:00.000Z  1501259958511443969
# 1  2022-03-08T18:13:54.000Z  1501255817051394055
# 2  2022-03-08T18:13:48.000Z  1501259905298165760
# 3  2022-03-08T18:13:25.000Z  1501259812394446860
# 4  2022-03-08T18:13:18.000Z  1501259781876568071
#
#                                                 text  retweets  replies  \
# 0  I’ll eat salad and green juice and coffeee my ...         0        0
# 1  @KevinRothrock It is good for Russian's health...         0        0
# 2  RT @Pinealpodcast: Why do you know the names o...         3        0
# ...

# %%
print("Proportion of topic 0: ", len(topics_tweets[topics_tweets['Topic_0'] >=0.5]) / len(topics_tweets)) 

print("Proportion of topic 1: ", len(topics_tweets[topics_tweets['Topic_1'] >=0.5]) / len(topics_tweets)) 

print("Proportion of topic 2: ", len(topics_tweets[topics_tweets['Topic_2'] >=0.5]) / len(topics_tweets)) 

#proportion of topics 0 are the most common in the dataset, but tweets can be more than one topic
# Out:
# Proportion of topic 0:  0.5925261144622628
# Proportion of topic 1:  0.11790495806973665
# Proportion of topic 2:  0.20176548477269385

# %%
#I'm curious if topic 0 really has more moralistic percentages than the rest of them given the negative words overall 
topic0tweets = topics_tweets[topics_tweets['Topic_0'] > 0.50]

print(len(topic0tweets))
#biggest topic 

topic0text = topic0tweets['clean_text']
# Out:
# 20137

# %%
topic0_moral_per = topic0text.apply(simple_moralistic_perc)

# %%
plt.hist(topic0_moral_per)
plt.title("Topic 0 Moralistic Tweets")
plt.ylabel("Number of Tweets")
plt.xlabel("Proportion Moralistic Language");

# %%
moral_percentage(topic0_moral_per)
# Out:
# Number of moralistic tweets:  2275
# Percentage of moralistic in full sample:  11.29761136216914

# %%
#how does this compare to topic 1?
topic1tweets = topics_tweets[topics_tweets['Topic_1'] > 0.50]
print(len(topic1tweets))

topic1text = topic1tweets['clean_text']
# Out:
# 4007

# %%
topic1_moral_per = topic1text.apply(simple_moralistic_perc)

# %%
plt.hist(topic1_moral_per)
plt.title("Topic 1 Moralistic Tweets")
plt.ylabel("Number of Tweets")
plt.xlabel("Proportion Moralistic Language");

# %%
moral_percentage(topic1_moral_per)
#much lower
# Out:
# Number of moralistic tweets:  124
# Percentage of moralistic in full sample:  3.094584477164961

# %%
#how does this compare to topic 2?
topic2tweets = topics_tweets[topics_tweets['Topic_2'] > 0.50]

print(len(topic2tweets))

topic2text = topic2tweets['clean_text']
# Out:
# 6857

# %%
topic2_moral_per = topic2text.apply(simple_moralistic_perc)

# %%
plt.hist(topic2_moral_per)
plt.title("Topic 2 Moralistic Tweets")
plt.ylabel("Number of Tweets")
plt.xlabel("Proportion Moralistic Language");

# %%
moral_percentage(topic2_moral_per)
#the same as topic 1 - interesting! but much lower than topic 0
# Out:
# Number of moralistic tweets:  228
# Percentage of moralistic in full sample:  3.3250692722765054

# %%
#plot all Topic moralistic graphs together

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (10,5))
fig.suptitle('Proportion of Moralistic Tweets by Topic')

ax1.hist(topic0_moral_per)
ax1.set_title("Topic 0: 11.3% Moralistic")

ax2.hist(topic1_moral_per)
ax2.set_title("Topic 1: 3.1% Moralistic")

ax3.hist(topic2_moral_per)
ax3.set_title("Topic 2: 3.3% Moralistic");

# %%
#let's look at whether sentiment differs by topic 
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
from statistics import mean

# %%
def mean_compound_score(topic_texts): 
    
    topic_compound_scores =[]

    for tweet in topic_texts: 
        topic_compound_scores.append(sia.polarity_scores(tweet)['compound']) 

    print(mean(topic_compound_scores))

# %%
mean_compound_score(topic0text)
mean_compound_score(topic1text)
mean_compound_score(topic2text)
#topic 0 is the most negative, 1 is the most positive and 2 is neutral/mixed
# Out:
# 0.2571295972587774
# 0.7409373346643374
# 0.532909902289631

# %% [markdown]
# # Re-do Topic Modeling on "Diet Culture" Topic 0
#
# I am most interested in this topic 0 since it is the largest, most moralistic, and most negative topic. It also tends to have words associated the most with Diet Culture. I want to explore it a bit more to see if we can pick up on any more in-depth topics within this.

# %%
topic0tweets.head()
# Out:
#    level_0  index             tweet_id           author_id  \
# 0        0      0  1501259958511443969          4909860786
# 1        1      1  1501259930141036545  968843336961290241
# 2        2      2  1501259905298165760             7610242
# 3        4      4  1501259812394446860          1863340376
# 6        8      8  1501259738218070018            39999688
#
#            tweet_created_at      conversation_id  \
# 0  2022-03-08T18:14:00.000Z  1501259958511443969
# 1  2022-03-08T18:13:54.000Z  1501255817051394055
# 2  2022-03-08T18:13:48.000Z  1501259905298165760
# 3  2022-03-08T18:13:25.000Z  1501259812394446860
# 6  2022-03-08T18:13:08.000Z  1501243646363983877
#
#                                                 text  retweets  replies  \
# 0  I’ll eat salad and green juice and coffeee my ...         0        0
# 1  @KevinRothrock It is good for Russian's health...         0        0
# 2  RT @Pinealpodcast: Why do you know the names o...         3        0
# ...

# %%
topic0tweets.reset_index(drop = True, inplace=True)

# %%
topic0tweets.drop(['Topic_0', 'Topic_1', 'Topic_2', 'index', 'level_0'], axis = 1, inplace=True)
# Out:
# /Users/jadebenson/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
t0_tweets = topic0tweets["clean_text"]

# %%
t0_lemmas = [get_lemmas(tweet) for tweet in t0_tweets]

# %%
bigram_0 = models.Phrases(t0_lemmas, min_count = 5)
bigram_mod_0 = models.phrases.Phraser(bigram_0)
bigram_lemmas_0 = [bigram_mod_0[word] for word in t0_lemmas]

# %%
dictionary_0 = corpora.Dictionary(bigram_lemmas_0)
bow_corpus_0 = [dictionary_0.doc2bow(text) for text in bigram_lemmas_0]

# %%
calc_plot_coherence(2, 10, bow_corpus_0, dictionary_0, bigram_lemmas_0)
# Out:
# Topics: 2
# number of topics:  2 u mass coherence:  -2.8082083929284387
# Topics: 3
# number of topics:  3 u mass coherence:  -3.103573336133627
# Topics: 4
# number of topics:  4 u mass coherence:  -3.2368857065733447
# Topics: 5
# number of topics:  5 u mass coherence:  -3.438253297166699
# Topics: 6
# number of topics:  6 u mass coherence:  -4.942644860922125
# Topics: 7
# number of topics:  7 u mass coherence:  -7.9091175022381455
# Topics: 8
# number of topics:  8 u mass coherence:  -9.365878613406355
# Topics: 9
# number of topics:  9 u mass coherence:  -10.355997068751435

# %%
LDA_visualize(bow_corpus_0, 2, dictionary_0, 5, 1000, 10, 'auto', 'auto', "topic0_maxc")
# Out:
# coherence is:  -2.8082083929284387
# [(0,
#   '0.061*"eat" + 0.060*"healthy" + 0.014*"get" + 0.012*"make" + 0.010*"want" + '
#   '0.009*"like" + 0.009*"try" + 0.008*"food" + 0.007*"time" + 0.007*"one"'),
#  (1,
#   '0.065*"food" + 0.054*"diet" + 0.025*"eat" + 0.009*"like" + 0.008*"people" + '
#   '0.007*"need" + 0.006*"healthy" + 0.006*"much" + 0.006*"fat" + 0.006*"body"')]
# /Users/jadebenson/opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/jadebenson/opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# ...

# %% [markdown]
# This doesn't really add too much more to the analysis. With a salience of 0, the two topics look to be about topic 1 veganism and topic 2 specific meals and everything else. I won't continue with this since I don't see this adding too much more.

# %% [markdown]
# ## Network Analysis
#
# I'm curious about what the reply networks look like - do the users who are responding to each other a part of one topic more prominently than the other? Are they in pretty separate communities? Particularly Topics 0 and 2.

# %%
topics_tweets.head()
# Out:
#    level_0  index             tweet_id            author_id  \
# 0        0      0  1501259958511443969           4909860786
# 1        1      1  1501259930141036545   968843336961290241
# 2        2      2  1501259905298165760              7610242
# 3        4      4  1501259812394446860           1863340376
# 4        5      5  1501259781876568071  1000009052615659520
#
#            tweet_created_at      conversation_id  \
# 0  2022-03-08T18:14:00.000Z  1501259958511443969
# 1  2022-03-08T18:13:54.000Z  1501255817051394055
# 2  2022-03-08T18:13:48.000Z  1501259905298165760
# 3  2022-03-08T18:13:25.000Z  1501259812394446860
# 4  2022-03-08T18:13:18.000Z  1501259781876568071
#
#                                                 text  retweets  replies  \
# 0  I’ll eat salad and green juice and coffeee my ...         0        0
# 1  @KevinRothrock It is good for Russian's health...         0        0
# 2  RT @Pinealpodcast: Why do you know the names o...         3        0
# ...

# %%
len(topics_tweets)
# Out:
# 33985

# %%
replies = topics_tweets[topics_tweets['type_reference'] == 'replied_to']

# %%
len(replies)
#there are a lot of replies in this dataset (about 1/3)
# Out:
# 12423

# %%
replies.head()
# Out:
#     level_0  index             tweet_id            author_id  \
# 1         1      1  1501259930141036545   968843336961290241
# 6         8      8  1501259738218070018             39999688
# 16       18     18  1501259398609612807  1326220881086078979
# 17       19     19  1501259391458230278  1323386330370527234
# 19       21     21  1501259346142846978  1431003624189136902
#
#             tweet_created_at      conversation_id  \
# 1   2022-03-08T18:13:54.000Z  1501255817051394055
# 6   2022-03-08T18:13:08.000Z  1501243646363983877
# 16  2022-03-08T18:11:47.000Z  1501254786418675713
# 17  2022-03-08T18:11:45.000Z  1501255972626612227
# 19  2022-03-08T18:11:34.000Z  1501258524785061890
#
#                                                  text  retweets  replies  \
# 1   @KevinRothrock It is good for Russian's health...         0        0
# 6   @SteveWeberFW @BlazejDzik @Jessicam6946 @McDon...         0        0
# ...

# %%
print("Proportion of topic 0 in replies: ", len(replies[replies['Topic_0'] >0.5]) / len(replies)) 

print("Proportion of topic 1 in replies: ", len(replies[replies['Topic_1'] >0.5]) / len(replies)) 

print("Proportion of topic 2 in replies: ", len(replies[replies['Topic_2'] >0.5]) / len(replies)) 

#proportion of topic 0 is much higher than in the overall dataset where it was only like
# Out:
# Proportion of topic 0 in replies:  0.7315463253642437
# Proportion of topic 1 in replies:  0.1652579892135555
# Proportion of topic 2 in replies:  0.0462046204620462

# %%
#I think this is too big to plot a network well 
#let's just pick a small sample from it 
#maybe top 100 so we can see what's going on 
#let's pick the most popular replies by the number of replies and likes

# %%
popular_replies = replies.sort_values(['replies', 'likes'], ascending=False)

# %%
popular_replies.head()
# Out:
#        level_0  index             tweet_id   author_id  \
# 8581      9379  14907  1500712502098751493    31473986
# 29697    33771  60022  1499050060566478855    21547951
# 31472    35693  64358  1498921198184505347    72592593
# 4628      5072   7784  1500959809067175945  2508978926
# 9929     10989  17525  1500608477680570373   155218344
#
#                tweet_created_at      conversation_id  \
# 8581   2022-03-07T05:58:37.000Z  1500631218567757827
# 29697  2022-03-02T15:52:40.000Z  1489249431618605058
# 31472  2022-03-02T07:20:36.000Z  1498916334834528256
# 4628   2022-03-07T22:21:19.000Z  1500928760673153033
# 9929   2022-03-06T23:05:15.000Z  1500606652600537097
#
#                                                     text  retweets  replies  \
# 8581   @24talk I was asked why I still wear a mask.  ...        14       65
# 29697  @OonaHanson They should stop selling junk. May...         0       56
# 31472  @Morris_Monye There's hunger and despair in th...        50       38
# ...

# %%
top_100_pop_replies = popular_replies.iloc[0:100,:]

# %%
len(top_100_pop_replies[top_100_pop_replies['Topic_0']>0.5])/len(top_100_pop_replies)
#even bigger among the most popular replies
# Out:
# 0.9

# %%
top_100_pop_replies_edges = top_100_pop_replies[['replied_to_user', 'author_id']]

# %%
import networkx as nx

#want directed graph where we see those that are replying to whom
G = nx.DiGraph(directed = True)

# %%
#want to create list of tuples where original tweeter -> replier

#that way we can see which users had the most influence 
#list of tuples replied to user, author_id 
records = top_100_pop_replies_edges.to_records(index=False)

result = list(records)

# %%
#df, source, target, weights
G.add_edges_from(result, weight=1)

# %%
nx.draw(G)
#I think those nodes in the middle should be the most replied to

# %% [markdown]
# There's not much that I think this is adding to the analysis except that the majority of replies, especially the popular ones are related to diet culture tweets.
